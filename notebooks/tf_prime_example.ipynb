# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import h5py
import numpy as np
import tensorflow as tf
tf.config.experimental.enable_tensor_float_32_execution(False)
import baskerville
from baskerville import seqnn
import json

# %%
model_file = "model0_best.h5" #select fold
params_file = 'params.json' # from Calico repo

# %%
# %%capture
#Take
with open(params_file) as params_open :
    params = json.load(params_open)
    params_model = params['model']
    params_train = params['train']
    
params_model['verbose'] = True

seqnn_model = seqnn.SeqNN(params_model)
seqnn_model.restore(model_file, 0)

# %%
slices = [3645, 3646, 3647] # gtex blood tracks

# %%
sequence_one_hot_wt = np.load('../wt_seq.npy')
wt_pred_across_folds_tf = seqnn_model(sequence_one_hot_wt[None, ...])[..., slices]

# %%
wt_pred_across_folds_tf.shape
# Out:
# (1, 12288, 3)

# %%
wt_pred_across_folds_tf
# Out:
# array([[[1.4176325e-02, 4.9702176e-03, 2.2553071e-02],
#         [1.4020229e-02, 4.9372860e-03, 2.0984918e-02],
#         [1.6354196e-02, 5.3479373e-03, 2.4030909e-02],
#         ...,
#         [4.6395662e-04, 4.6800509e-05, 5.3354498e-04],
#         [4.0579381e-04, 4.1927251e-05, 4.6345149e-04],
#         [4.0390174e-04, 4.1422121e-05, 4.5429787e-04]]], dtype=float32)

# %%
np.save('wt_pred_across_folds', wt_pred_across_folds_tf)
